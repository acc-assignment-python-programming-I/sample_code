# %% [markdown]
# # Python Fundamentals - Chapter 3:
#
# ## 1. **The if Statement**:
#    - Used to execute a block of code only if a specified condition is true. If the condition is false, the block is skipped.

# %%
# The if statement allows you to execute a block of code only if a condition is true.
# Example: Checking if a number is positive

number = 10
if number > 0:
    print("The number is positive.")  # This will be printed because the condition is true
# Out:
# The number is positive.

# %% [markdown]
# ## 2. **The if-else Statement**:
#    - Provides two paths of execution. One path is taken if the condition is true, and the other path is taken if the condition is false.

# %%
# The if-else statement allows you to choose between two blocks of code to execute based on a condition.
# Example: Checking if a number is even or odd

number = 5
if number % 2 == 0:
    print("The number is even.")  # This block will be executed if the number is even
else:
    print("The number is odd.")  # This block will be executed if the number is odd
# Out:
# The number is odd.

# %% [markdown]
# ## 3. **Comparing Strings**:
#    - Strings can be compared using relational operators. The comparison is case-sensitive and checks character by character based on ASCII values.

# %%
# Strings can be compared using relational operators such as == and !=.
# Example: Comparing two strings

string1 = "hello"
string2 = "world"
if string1 == string2:
    print("The strings are equal.")  # This will not be printed because the strings are not equal
else:
    print("The strings are not equal.")  # This will be printed because the strings are not equal
# Out:
# The strings are not equal.

# %% [markdown]
# ## 4. **Nested Decision Structures and the if-elif-else Statement**: (Follow)
#    - Allows you to create more complex decision structures by nesting if statements or using if-elif-else statements for multiple conditions.
#    - Decision Structure and Boolean Logic. Learning Objectives:
#         - Understand boolean logic and logical operators
#         - Understand If/Else statements and program flow

# %%
# You can nest decision structures within each other to handle multiple conditions.
# The if-elif-else statement simplifies the structure by allowing multiple conditions to be checked sequentially.
# Example: Determining grade based on score

score = 85
if score >= 90:
    grade = 'A'
elif score >= 80:
    grade = 'B'  # This block will be executed because the score is between 80 and 89
elif score >= 70:
    grade = 'C'
elif score >= 60:
    grade = 'D'
else:
    grade = 'F'
print(f"Your grade is: {grade}")
# Out:
# Your grade is: B

# %%
#Add comments below 

day = int(input('Enter a number (1-7) for the day of the week: '))

if day == 1:
    print('Monday')
elif day == 2:
    print('Tuesday')
elif day == 3:
    print('Wednesday')
elif day == 4:
    print ('Thursday')
elif day == 5:
    print ('Friday')
elif day == 6:
    print ('Saturday')
elif day == 7:
    print ('Sunday')
else:
    print ('Error: Please enter a number in the range 1-7.')

# %% [markdown]
# Enter a number (1-7) for the day of the week: 1
# Monday
# After running this program, think about and answer these questions:
#
# What is the program doing?
# Does every line in the code execute, explain?
# Could you find a way to break it?

# %% [markdown]
# ## 5. **Logical Operators**:
#    - Used to combine multiple conditions in a single if statement. The `and` operator requires all conditions to be true, while the `or` operator requires at least one condition to be true.

# %%
# Logical operators (and, or, not) allow you to combine multiple conditions in a single if statement.
# Example: Checking if a number is within a specific range

number = 15
if number >= 10 and number <= 20:
    print("The number is within the range of 10 to 20.")  # This will be printed because the condition is true
# Out:
# The number is within the range of 10 to 20.

# %% [markdown]
# ## 6. **Boolean Variables**:
#    - Store True or False values. They are often used as flags to indicate whether certain conditions are met.

# %%
# Boolean variables can store True or False values and are often used as flags to indicate whether a condition is met.
# Example: Using a boolean variable as a flag

is_sunny = True
if is_sunny:
    print("It is sunny outside.")  # This will be printed because is_sunny is True
else:
    print("It is not sunny outside.")
# Out:
# It is sunny outside.

# %% [markdown]
# ## 7. **Turtle Graphics**:
#    - The Turtle module allows for drawing and moving a turtle on the screen. You can control the turtle's behavior based on its state using decision structures.

# %%
# The Turtle module in Python allows for unique graphics and visualizations. You can use decision structures to control the turtle's behavior.
# Example: Moving the turtle based on its position
# Import necessary libraries
import turtle
turtle.setup(500, 500)  # Set up the window size
t = turtle.Turtle()  # Create a new turtle
t.penup()  # Lift the pen so it doesn't draw
t.goto(100, 100)  # Move the turtle to position (100, 100)

# Check the turtle's position and move it if it's within a certain range
if t.xcor() > 50 and t.ycor() > 50:
    t.pendown()  # Lower the pen to start drawing
    t.goto(0, 0)  # Move the turtle to the origin (0, 0)
    
turtle.done()  # Finish the turtle graphics
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[1], line 5
#       1 # The Turtle module in Python allows for unique graphics and visualizations. You can use decision structures to control the turtle's behavior.
#       2 # Example: Moving the turtle based on its position
#       3 # Import necessary libraries
#       4 import turtle
# ----> 5 turtle.setup(500, 500)  # Set up the window size
#       6 t = turtle.Turtle()  # Create a new turtle
#       7 t.penup()  # Lift the pen so it doesn't draw
#
# File <string>:6, in setup(width, height, startx, starty)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/turtle.py:3663, in Screen()
#    3659 """Return the singleton screen object.
#    3660 If none exists at the moment, create a new one and return it,
#    3661 else return the existing one."""
#    3662 if Turtle._screen is None:
# -> 3663     Turtle._screen = _Screen()
#    3664 return Turtle._screen
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/turtle.py:3691, in _Screen.__init__(self)
#    3689 self._root.setupcanvas(width, height, canvwidth, canvheight)
#    3690 _Screen._canvas = self._root._getcanvas()
# -> 3691 TurtleScreen.__init__(self, _Screen._canvas)
#    3692 self.setup(width, height, leftright, topbottom)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/turtle.py:996, in TurtleScreen.__init__(self, cv, mode, colormode, delay)
#     994 self._colormode = _CFG["colormode"]
#     995 self._keys = []
# --> 996 self.clear()
#     997 if sys.platform == 'darwin':
#     998     # Force Turtle window to the front on OS X. This is needed because
#     999     # the Turtle window will show behind the Terminal window when you
#    1000     # start the demo from the command line.
#    1001     rootwindow = cv.winfo_toplevel()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/turtle.py:1028, in TurtleScreen.clear(self)
#    1026 self.bgcolor("white")
#    1027 for btn in 1, 2, 3:
# -> 1028     self.onclick(None, btn)
#    1029 self.onkeypress(None)
#    1030 for key in self._keys[:]:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/turtle.py:1365, in TurtleScreen.onclick(self, fun, btn, add)
#    1350 def onclick(self, fun, btn=1, add=None):
#    1351     """Bind fun to mouse-click event on canvas.
#    1352
#    1353     Arguments:
#    (...)
#    1363     >>> screen.onclick(None)
#    1364     """
# -> 1365     self._onscreenclick(fun, btn, add)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/turtle.py:669, in TurtleScreenBase._onscreenclick(self, fun, num, add)
#     660 """Bind fun to mouse-click event on canvas.
#     661 fun must be a function with two arguments, the coordinates
#     662 of the clicked point on the canvas.
#    (...)
#     666 then _onscreensclick-event.
#     667 """
#     668 if fun is None:
# --> 669     self.cv.unbind("<Button-%s>" % num)
#     670 else:
#     671     def eventfun(event):
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/turtle.py:422, in ScrolledCanvas.unbind(self, *args, **kwargs)
#     419 def unbind(self, *args, **kwargs):
#     420     """ 'forward' method, which canvas itself has inherited...
#     421     """
# --> 422     self._canvas.unbind(*args, **kwargs)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/tkinter/__init__.py:1397, in Misc.unbind(self, sequence, funcid)
#    1394 def unbind(self, sequence, funcid=None):
#    1395     """Unbind for this widget for event SEQUENCE  the
#    1396     function identified with FUNCID."""
# -> 1397     self.tk.call('bind', self._w, sequence, '')
#    1398     if funcid:
#    1399         self.deletecommand(funcid)
#
# TclError: can't invoke "bind" command:  application has been destroyed
